# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('baywheels_2019')
df.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_28436\347467546.py:1: DtypeWarning: Columns (3,4,5,6,7,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('baywheels_2019')
#    Unnamed: 0           start_time             end_time start_station_id  \
# 0           0  2019-10-28 09:46:47  2019-10-28 09:51:05             50.0
# 1           1  2019-08-10 19:31:02  2019-08-10 19:35:05            285.0
# 2           2  2019-05-27 13:18:58  2019-05-27 13:46:37             10.0
# 3           3  2019-07-24 22:47:58  2019-07-24 22:52:48            106.0
# 4           4  2019-04-28 17:26:22  2019-04-28 17:31:54             80.0
#
#   start_station_lat start_station_lon end_station_id end_station_lat  \
# 0         37.780526       -122.390288          453.0       37.777934
# 1         37.783521       -122.431158           74.0       37.776435
# 2         37.795393        -122.40477          399.0       37.802636
# 3         37.763242       -122.430675           72.0       37.772406
# 4         37.775235       -122.397437           50.0       37.780526
#
#   end_station_lon   bike_id
# 0     -122.396973   12424.0
# 1     -122.426244    1718.0
# 2     -122.436289     608.0
# 3      -122.43565  551642.0
# 4     -122.390288    1103.0

# %%
df.dtypes
# Out:
# Unnamed: 0            int64
# start_time           object
# end_time             object
# start_station_id     object
# start_station_lat    object
# start_station_lon    object
# end_station_id       object
# end_station_lat      object
# end_station_lon      object
# bike_id              object
# dtype: object

# %%
df['start_time_formatted'] = pd.to_datetime(df['start_time'])
df.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\_libs\tslib.pyx:605, in pandas._libs.tslib.array_to_datetime()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:318, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File ~\anaconda3\lib\site-packages\dateutil\parser\_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File ~\anaconda3\lib\site-packages\dateutil\parser\_parser.py:643, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     642 if res is None:
# --> 643     raise ParserError("Unknown string format: %s", timestr)
#     645 if len(res) == 0:
#
# ParserError: Unknown string format: Failure
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\_libs\tslib.pyx:616, in pandas._libs.tslib.array_to_datetime()
#
# TypeError: invalid string coercion to datetime for "Failure" at position 381556
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df['start_time_formatted'] = pd.to_datetime(df['start_time'])
#       2 df.head()
#
# File ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066         result = arg.map(cache_array)
#    1067     else:
# -> 1068         values = convert_listlike(arg._values, format)
#    1069         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1070 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:438, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     436 assert format is None or infer_datetime_format
#     437 utc = tz == "utc"
# --> 438 result, tz_parsed = objects_to_datetime64ns(
#     439     arg,
#     440     dayfirst=dayfirst,
#     441     yearfirst=yearfirst,
#     442     utc=utc,
#     443     errors=errors,
#     444     require_iso8601=require_iso8601,
#     445     allow_object=True,
#     446 )
#     448 if tz_parsed is not None:
#     449     # We can take a shortcut since the datetime64 numpy array
#     450     # is in UTC
#     451     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File ~\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:2177, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2175 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2176 try:
# -> 2177     result, tz_parsed = tslib.array_to_datetime(
#    2178         data.ravel("K"),
#    2179         errors=errors,
#    2180         utc=utc,
#    2181         dayfirst=dayfirst,
#    2182         yearfirst=yearfirst,
#    2183         require_iso8601=require_iso8601,
#    2184         allow_mixed=allow_mixed,
#    2185     )
#    2186     result = result.reshape(data.shape, order=order)
#    2187 except OverflowError as err:
#    2188     # Exception is raised when a part of date is greater than 32 bit signed int
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\tslib.pyx:427, in pandas._libs.tslib.array_to_datetime()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\tslib.pyx:683, in pandas._libs.tslib.array_to_datetime()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\tslib.pyx:829, in pandas._libs.tslib._array_to_datetime_object()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\tslib.pyx:819, in pandas._libs.tslib._array_to_datetime_object()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:318, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File ~\anaconda3\lib\site-packages\dateutil\parser\_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1366     return parser(parserinfo).parse(timestr, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File ~\anaconda3\lib\site-packages\dateutil\parser\_parser.py:643, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     640 res, skipped_tokens = self._parse(timestr, **kwargs)
#     642 if res is None:
# --> 643     raise ParserError("Unknown string format: %s", timestr)
#     645 if len(res) == 0:
#     646     raise ParserError("String does not contain a date: %s", timestr)
#
# ParserError: Unknown string format: Failure present at position 381556

# %%
## First Attemt to convert the strt_time into a time format failed because there are corrupted values in certain rows of the df.
## From the ParseError Message we could identify the error. Some values are filled with the value "Failure". Lets erase those
print(df.loc[[381556]])
# Out:
#         Unnamed: 0 start_time end_time start_station_id start_station_lat  \
# 381556      381556    Failure  Failure          Failure           Failure
#
#        start_station_lon end_station_id end_station_lat end_station_lon  \
# 381556           Failure        Failure         Failure         Failure
#
#         bike_id
# 381556  Failure

# %%
df_clean1 = df.drop(df[df.start_time == 'Failure'].index)
df_clean1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2506993 entries, 0 to 2507002
# Data columns (total 10 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Unnamed: 0         int64
#  1   start_time         object
#  2   end_time           object
#  3   start_station_id   object
#  4   start_station_lat  object
#  5   start_station_lon  object
#  6   end_station_id     object
#  7   end_station_lat    object
#  8   end_station_lon    object
#  9   bike_id            object
# dtypes: int64(1), object(9)
# memory usage: 210.4+ MB

# %%
df_clean1['start_time_formatted'] = pd.to_datetime(df_clean1['start_time'])
df_clean1['end_time_formatted'] = pd.to_datetime(df_clean1['end_time'])

df_clean1.head()
# Out:
#    Unnamed: 0           start_time             end_time start_station_id  \
# 0           0  2019-10-28 09:46:47  2019-10-28 09:51:05             50.0
# 1           1  2019-08-10 19:31:02  2019-08-10 19:35:05            285.0
# 2           2  2019-05-27 13:18:58  2019-05-27 13:46:37             10.0
# 3           3  2019-07-24 22:47:58  2019-07-24 22:52:48            106.0
# 4           4  2019-04-28 17:26:22  2019-04-28 17:31:54             80.0
#
#   start_station_lat start_station_lon end_station_id end_station_lat  \
# 0         37.780526       -122.390288          453.0       37.777934
# 1         37.783521       -122.431158           74.0       37.776435
# 2         37.795393        -122.40477          399.0       37.802636
# 3         37.763242       -122.430675           72.0       37.772406
# 4         37.775235       -122.397437           50.0       37.780526
#
#   end_station_lon   bike_id start_time_formatted  end_time_formatted
# 0     -122.396973   12424.0  2019-10-28 09:46:47 2019-10-28 09:51:05
# 1     -122.426244    1718.0  2019-08-10 19:31:02 2019-08-10 19:35:05
# 2     -122.436289     608.0  2019-05-27 13:18:58 2019-05-27 13:46:37
# 3      -122.43565  551642.0  2019-07-24 22:47:58 2019-07-24 22:52:48
# 4     -122.390288    1103.0  2019-04-28 17:26:22 2019-04-28 17:31:54

# %%
df_clean1.dtypes
# Out:
# Unnamed: 0                       int64
# start_time                      object
# end_time                        object
# start_station_id                object
# start_station_lat               object
# start_station_lon               object
# end_station_id                  object
# end_station_lat                 object
# end_station_lon                 object
# bike_id                         object
# start_time_formatted    datetime64[ns]
# end_time_formatted      datetime64[ns]
# dtype: object

# %%
#after this command, df_clean2 includes properly formatted start and end times.
df_clean2 = df_clean1.drop(['start_time', 'end_time', 'Unnamed: 0'], axis=1)
df_clean2
# Out:
#         start_station_id start_station_lat start_station_lon end_station_id  \
# 0                   50.0         37.780526       -122.390288          453.0
# 1                  285.0         37.783521       -122.431158           74.0
# 2                   10.0         37.795393        -122.40477          399.0
# 3                  106.0         37.763242       -122.430675           72.0
# 4                   80.0         37.775235       -122.397437           50.0
# ...                  ...               ...               ...            ...
# 2506998            109.0         37.763316       -122.421904          381.0
# 2506999             58.0         37.776619       -122.417385            5.0
# 2507000             23.0         37.791464       -122.391034           15.0
# 2507001             23.0         37.791464       -122.391034          364.0
# 2507002             64.0         37.776754       -122.399018            3.0
#
#         end_station_lat end_station_lon   bike_id start_time_formatted  \
# 0             37.777934     -122.396973   12424.0  2019-10-28 09:46:47
# 1             37.776435     -122.426244    1718.0  2019-08-10 19:31:02
# 2             37.802636     -122.436289     608.0  2019-05-27 13:18:58
# 3             37.772406      -122.43565  551642.0  2019-07-24 22:47:58
# 4             37.780526     -122.390288    1103.0  2019-04-28 17:26:22
# ...                 ...             ...       ...                  ...
# 2506998       37.758238     -122.426094    6118.0  2019-04-12 19:11:48
# 2506999       37.783899     -122.408445    1479.0  2019-07-16 19:02:32
# 2507000       37.795392     -122.394203    1742.0  2019-05-29 16:03:26
# 2507001          37.772      -122.38997   10107.0  2019-08-19 08:32:17
# 2507002       37.786375     -122.404904    5359.0  2019-04-02 17:00:36
#
#          end_time_formatted
# 0       2019-10-28 09:51:05
# 1       2019-08-10 19:35:05
# 2       2019-05-27 13:46:37
# 3       2019-07-24 22:52:48
# 4       2019-04-28 17:31:54
# ...                     ...
# 2506998 2019-04-12 19:17:34
# 2506999 2019-07-16 19:06:54
# 2507000 2019-05-29 16:09:25
# 2507001 2019-08-19 08:41:26
# 2507002 2019-04-02 17:06:28
#
# [2506993 rows x 9 columns]

# %%
## next step is to properly format the other values. We are starting with start_station_id and receive an error because there are NAN values in the df
df_clean1=df_clean1.astype({"start_station_id":int})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 ## next step is to properly format the other values. We are starting with start_station_id and receive an error because there are NAN values in the df
# ----> 2 df_clean1=df_clean1.astype({"start_station_id":int})
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:6226, in NDFrame.astype(self, dtype, copy, errors)
#    6224             res_col = col.copy() if copy else col
#    6225         else:
# -> 6226             res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    6227         results.append(res_col)
#    6229 elif is_extension_array_dtype(dtype) and self.ndim > 1:
#    6230     # GH 18099/22869: columnwise conversion to extension dtype
#    6231     # GH 24704: use iloc to handle duplicate column names
#    6232     # TODO(EA2D): special case not needed with 2D EAs
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
#     447 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:526, in Block.astype(self, dtype, copy, errors)
#     508 """
#     509 Coerce to the new dtype.
#     510
#    (...)
#     522 Block
#     523 """
#     524 values = self.values
# --> 526 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     528 new_values = maybe_coerce_values(new_values)
#     529 newb = self.make_block(new_values)
#
# File ~\anaconda3\lib\site-packages\pandas\core\dtypes\astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File ~\anaconda3\lib\site-packages\pandas\core\dtypes\astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\anaconda3\lib\site-packages\pandas\core\dtypes\astype.py:170, in astype_nansafe(arr, dtype, copy, skipna)
#     166     raise ValueError(msg)
#     168 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169     # Explicit copy, or required since NumPy can't view from / to object.
# --> 170     return arr.astype(dtype, copy=True)
#     172 return arr.astype(dtype, copy=copy)
#
# ValueError: cannot convert float NaN to integer

# %%
# we found that 80734 start_station_ids are not filled properly. That number is too high to just drop the rows
df_count = len(df_clean1[df_clean1['start_station_id'].isna()])
df_count
# Out:
# 80734

# %%
#df_clean1['bike_id'] = le.fit_transform(df_clean1['bike_id'].astype(str))
df_clean2['bike_id'] = df_clean2['bike_id'].apply(str)
#df_sorted=df_clean1.sort_values('bike_id')
#df_sorted.head()

# %%
df_sorted=df_clean2.sort_values(['bike_id', 'start_time_formatted'], ascending = [True, True])
df_sorted.head(25)
# Out:
#         start_station_id start_station_lat start_station_lon end_station_id  \
# 1459031            468.0         37.866289        -121.91261          312.0
# 1971590            231.0     37.3529503333   -122.2876776667          195.0
# 315417              92.0         37.773503       -122.402113          258.0
# 1590064            395.0         37.778562       -122.415787          424.0
# 820394             436.0          37.87031       -122.409794          398.0
# 1052707            195.0         37.791826        -122.41004          453.0
# 168697             236.0         37.803686       -122.282497          236.0
# 1314307            236.0         37.803686       -122.282497          219.0
# 2005541            219.0        37.8098236      -122.2801923          202.0
# 1153275            338.0     37.8031890811   -122.2705793381          186.0
# 2385323            186.0         37.801319       -122.262642          186.0
# 825555             186.0         37.801319       -122.262642          163.0
# 977394             163.0          37.79732        -122.26532          193.0
# 517522             182.0        37.8090126      -122.2682473          193.0
# 1854396              7.0         37.804562       -122.271738          200.0
# 272700             372.0         37.804037       -122.262409            7.0
# 338625               7.0     37.8045623549   -122.2717380524          182.0
# 1212352            182.0         37.809013       -122.268247          196.0
# 2002426            196.0      37.808893934   -122.2564601898          182.0
# 2039700            182.0         37.809013       -122.268247          195.0
# 45124              175.0         37.835946       -122.262366          204.0
# 156935             204.0         37.840186       -122.261822          154.0
# 1153619            239.0        37.8688126       -122.258764          266.0
# 607208             266.0        37.8624644      -122.2647911          246.0
# 1950627            253.0         37.866418       -122.253799          239.0
#
#         end_station_lat end_station_lon bike_id start_time_formatted  \
# 1459031       37.320142     -122.258498       .  2013-03-31 14:53:59
# 1971590   37.7913631667    -122.4376135       1  2013-07-13 14:21:22
# 315417        37.779629      -122.40988     1.0  2013-04-06 18:24:01
# 1590064       37.789803     -122.440438     1.0  2013-05-03 11:09:57
# 820394        37.332074       -122.4335     1.0  2013-06-11 20:19:55
# 1052707       37.301722     -122.412695     1.0  2013-06-19 21:12:10
# 168697        37.803686     -122.282497  1000.0  2019-01-03 08:18:20
# 1314307       37.809824     -122.280192  1000.0  2019-01-28 16:16:10
# 2005541      37.8007544    -122.2748943  1000.0  2019-01-29 08:27:37
# 1153275      37.8013189    -122.2626418  1000.0  2019-01-31 21:32:28
# 2385323       37.801319     -122.262642  1000.0  2019-02-03 21:59:32
# 825555         37.79732      -122.26532  1000.0  2019-02-06 08:53:14
# 977394        37.812744     -122.247215  1000.0  2019-02-06 18:27:35
# 517522       37.8127441    -122.2472152  1000.0  2019-02-07 18:44:01
# 1854396       37.800214      -122.25381  1000.0  2019-02-08 19:27:30
# 272700        37.804562     -122.271738  1000.0  2019-02-14 06:55:29
# 338625       37.8090126    -122.2682473  1000.0  2019-02-14 18:48:23
# 1212352       37.808894      -122.25646  1000.0  2019-02-14 18:58:09
# 2002426      37.8090126    -122.2682473  1000.0  2019-02-15 08:16:44
# 2039700       37.812314     -122.260779  1000.0  2019-02-15 17:47:42
# 45124         37.840186     -122.261822  1000.0  2019-03-07 10:44:04
# 156935        37.841924     -122.288045  1000.0  2019-03-08 07:37:28
# 1153619      37.8624644    -122.2647911  1000.0  2019-03-08 15:28:14
# 607208       37.8690599     -122.270556  1000.0  2019-03-08 18:34:37
# 1950627       37.868813     -122.258764  1000.0  2019-03-10 17:03:45
#
#          end_time_formatted
# 1459031 2019-10-07 17:55:34
# 1971590 2019-08-13 09:58:35
# 315417  2019-02-11 10:30:26
# 1590064 2019-05-23 20:25:53
# 820394  2019-01-30 14:08:55
# 1052707 2019-02-01 11:24:22
# 168697  2019-01-03 08:26:09
# 1314307 2019-01-28 16:19:08
# 2005541 2019-01-29 08:33:04
# 1153275 2019-01-31 21:36:42
# 2385323 2019-02-03 22:29:55
# 825555  2019-02-06 08:55:21
# 977394  2019-02-06 18:40:54
# 517522  2019-02-07 18:53:07
# 1854396 2019-02-08 19:38:59
# 272700  2019-02-14 06:59:51
# 338625  2019-02-14 18:50:57
# 1212352 2019-02-14 19:03:21
# 2002426 2019-02-15 08:24:38
# 2039700 2019-02-15 17:52:50
# 45124   2019-03-07 10:46:20
# 156935  2019-03-08 07:52:22
# 1153619 2019-03-08 15:33:10
# 607208  2019-03-08 18:41:56
# 1950627 2019-03-10 17:06:08

# %%
df_sort2=df_sorted.reset_index()
df_sort2 = df_sort2.drop(['index'], axis=1)
df_sort2.head()
# Out:
#   start_station_id start_station_lat start_station_lon end_station_id  \
# 0            468.0         37.866289        -121.91261          312.0
# 1            231.0     37.3529503333   -122.2876776667          195.0
# 2             92.0         37.773503       -122.402113          258.0
# 3            395.0         37.778562       -122.415787          424.0
# 4            436.0          37.87031       -122.409794          398.0
#
#   end_station_lat end_station_lon bike_id start_time_formatted  \
# 0       37.320142     -122.258498       .  2013-03-31 14:53:59
# 1   37.7913631667    -122.4376135       1  2013-07-13 14:21:22
# 2       37.779629      -122.40988     1.0  2013-04-06 18:24:01
# 3       37.789803     -122.440438     1.0  2013-05-03 11:09:57
# 4       37.332074       -122.4335     1.0  2013-06-11 20:19:55
#
#    end_time_formatted
# 0 2019-10-07 17:55:34
# 1 2019-08-13 09:58:35
# 2 2019-02-11 10:30:26
# 3 2019-05-23 20:25:53
# 4 2019-01-30 14:08:55

# %%
df_sort2['start_station_id'].fillna(df_sort2['end_station_id'].shift(), inplace=True)
df_sort2['end_station_id'].fillna(df_sort2['start_station_id'].shift(-1), inplace=True)
df_sort2.head()
# Out:
#   start_station_id start_station_lat start_station_lon end_station_id  \
# 0            468.0         37.866289        -121.91261          312.0
# 1            231.0     37.3529503333   -122.2876776667          195.0
# 2             92.0         37.773503       -122.402113          258.0
# 3            395.0         37.778562       -122.415787          424.0
# 4            436.0          37.87031       -122.409794          398.0
#
#   end_station_lat end_station_lon bike_id start_time_formatted  \
# 0       37.320142     -122.258498       .  2013-03-31 14:53:59
# 1   37.7913631667    -122.4376135       1  2013-07-13 14:21:22
# 2       37.779629      -122.40988     1.0  2013-04-06 18:24:01
# 3       37.789803     -122.440438     1.0  2013-05-03 11:09:57
# 4       37.332074       -122.4335     1.0  2013-06-11 20:19:55
#
#    end_time_formatted
# 0 2019-10-07 17:55:34
# 1 2019-08-13 09:58:35
# 2 2019-02-11 10:30:26
# 3 2019-05-23 20:25:53
# 4 2019-01-30 14:08:55

# %%
missing_start_station_id = df_sort2[df_sort2['start_station_id'].isna()]
print(missing_start_station_id)
# Out:
#         start_station_id start_station_lat start_station_lon end_station_id  \
# 7327                 NaN         37.335725       -121.877271            NaN
# 7328                 NaN         37.330162       -121.886358            NaN
# 7329                 NaN         37.329361       -121.902065          283.0
# 7331                 NaN         37.332987       -121.897594            NaN
# 7332                 NaN     37.3352443333   -121.8900121667          312.0
# ...                  ...               ...               ...            ...
# 2506988              NaN         37.775935       -122.392668            NaN
# 2506989              NaN         37.775925       -122.392526            NaN
# 2506990              NaN          37.77593       -122.392638            NaN
# 2506991              NaN         37.775904       -122.392551            NaN
# 2506992              NaN         37.775912       -122.392578           None
#
#         end_station_lat end_station_lon   bike_id start_time_formatted  \
# 7327           37.33016     -121.886136  100235.0  2019-11-29 21:19:54
# 7328          37.329349     -121.902055  100235.0  2019-11-30 14:09:03
# 7329          37.330264     -121.897702  100235.0  2019-12-06 13:41:44
# 7331          37.335268     -121.890062  100235.0  2019-12-13 11:13:04
# 7332          37.329732     -121.901782  100235.0  2019-12-13 16:34:28
# ...                 ...             ...       ...                  ...
# 2506988       37.775941     -122.392716  999941.0  2019-12-03 15:43:02
# 2506989        37.77605     -122.392549  999941.0  2019-12-08 01:15:35
# 2506990       37.775869     -122.392646  999941.0  2019-12-11 15:28:11
# 2506991       37.775879     -122.392585  999941.0  2019-12-19 16:50:20
# 2506992       37.775857     -122.392584  999941.0  2019-12-27 12:51:19
#
#          end_time_formatted
# 7327    2019-11-29 21:26:14
# 7328    2019-11-30 14:18:17
# 7329    2019-12-06 13:43:31
# 7331    2019-12-13 11:17:32
# 7332    2019-12-13 16:39:54
# ...                     ...
# 2506988 2019-12-03 15:44:12
# 2506989 2019-12-08 01:16:41
# 2506990 2019-12-11 15:29:59
# 2506991 2019-12-19 16:52:07
# 2506992 2019-12-27 12:52:25
#
# [79567 rows x 9 columns]

# %%
df_count2 = len(df_sort2[df_sort2['start_station_id'].isna()])
df_count2
# Out:
# 79567

# %%
# We sorted our data by bike_id and starting_time_formatted.
# Now we can try to fill in missing values for the starting_station_id by replacing NAN values with 
# the end_station_values of previous entries
x=len(df_sort2.index)
for i in range(x):
    if pd.isnull(df_sort2.loc[df_sort2.index[i], 'start_station_id']):
        df_sort2.loc[df_sort2.index[i], 'start_station_id']=df_sort2.loc[df_sort2.index[i-1], 'end_station_id']
    else:
        df_sort2.loc[df_sort2.index[i], 'start_station_id']=df_sort2.loc[df_sort2.index[i], 'start_station_id']
        #    if(pd.isnan(df_sorted['start_station_id'])):
df_count2 = len(df_sort2[df_sort2['start_station_id'].isna()])
df_count2

# %%
x=len(df_sort2.index)
print(x)

# %%
for index in df_sorted.index:
#    if df_sorted[df_sorted['start_station_id'].isna()]:
#        print(index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 for index in df_sorted.index:
# ----> 2     if df_sorted[df_sorted['start_station_id'].isna()]:
#       3         print(index)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df_count2 = len(df_sorted[df_sorted['start_station_id'].isna()])
df_count2
# Out:
# 80734

# %%
#new dataframe that can be used to merge the missing values
df_compare_start_station = df[['start_station_id', 'start_station_lat', 'start_station_lon']]
df4=df_compare_start_station.dropna().copy()
df4.drop_duplicates(inplace=True)

# %%
df4
# Out:
#         start_station_id start_station_lat start_station_lon
# 0                   50.0         37.780526       -122.390288
# 1                  285.0         37.783521       -122.431158
# 2                   10.0         37.795393        -122.40477
# 3                  106.0         37.763242       -122.430675
# 4                   80.0         37.775235       -122.397437
# ...                  ...               ...               ...
# 1682692            488.0     37.7226299219   -122.3924964666
# 1776459            228.0         37.778921       -121.870411
# 1790211            131.0         37.840978       -122.302756
# 1971590            231.0     37.3529503333   -122.2876776667
# 2029049            444.0     37.3711164134   -121.8813318014
#
# [922 rows x 3 columns]

# %%
df
# Out:
#          Unnamed: 0           start_time             end_time  \
# 0                 0  2019-10-28 09:46:47  2019-10-28 09:51:05
# 1                 1  2019-08-10 19:31:02  2019-08-10 19:35:05
# 2                 2  2019-05-27 13:18:58  2019-05-27 13:46:37
# 3                 3  2019-07-24 22:47:58  2019-07-24 22:52:48
# 4                 4  2019-04-28 17:26:22  2019-04-28 17:31:54
# ...             ...                  ...                  ...
# 2506998     2506998  2019-04-12 19:11:48  2019-04-12 19:17:34
# 2506999     2506999  2019-07-16 19:02:32  2019-07-16 19:06:54
# 2507000     2507000  2019-05-29 16:03:26  2019-05-29 16:09:25
# 2507001     2507001  2019-08-19 08:32:17  2019-08-19 08:41:26
# 2507002     2507002  2019-04-02 17:00:36  2019-04-02 17:06:28
#
#         start_station_id start_station_lat start_station_lon end_station_id  \
# 0                   50.0         37.780526       -122.390288          453.0
# 1                  285.0         37.783521       -122.431158           74.0
# 2                   10.0         37.795393        -122.40477          399.0
# 3                  106.0         37.763242       -122.430675           72.0
# 4                   80.0         37.775235       -122.397437           50.0
# ...                  ...               ...               ...            ...
# 2506998            109.0         37.763316       -122.421904          381.0
# 2506999             58.0         37.776619       -122.417385            5.0
# 2507000             23.0         37.791464       -122.391034           15.0
# 2507001             23.0         37.791464       -122.391034          364.0
# 2507002             64.0         37.776754       -122.399018            3.0
#
#         end_station_lat end_station_lon   bike_id
# 0             37.777934     -122.396973   12424.0
# 1             37.776435     -122.426244    1718.0
# 2             37.802636     -122.436289     608.0
# 3             37.772406      -122.43565  551642.0
# 4             37.780526     -122.390288    1103.0
# ...                 ...             ...       ...
# 2506998       37.758238     -122.426094    6118.0
# 2506999       37.783899     -122.408445    1479.0
# 2507000       37.795392     -122.394203    1742.0
# 2507001          37.772      -122.38997   10107.0
# 2507002       37.786375     -122.404904    5359.0
#
# [2507003 rows x 10 columns]

# %%
df_info3=pd.merge(df_info1,df4, on='start_station_id', how='left')
#df_info3.head()
#print(df_info1.start_station_id.unique().tolist())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 4
#       1 #df_info3=pd.merge(df_info1,df_info2, on='start_station_id', how='left')
#       2 #df_info3.head()
#       3 #print(df_info1.start_station_id.unique().tolist())
# ----> 4 df_info3 = pd.DataFrame(df_info2)
#       5 print(df_info3.drop_duplicates(subset = 'start_station_id'))
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:781, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     778 # For data is scalar
#     779 else:
#     780     if index is None or columns is None:
# --> 781         raise ValueError("DataFrame constructor not properly called!")
#     783     index = ensure_index(index)
#     784     columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!
